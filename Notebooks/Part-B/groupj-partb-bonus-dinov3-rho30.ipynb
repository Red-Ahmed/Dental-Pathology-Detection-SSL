# %%
RHO = 0.30                # <-- change per run: 0.10, 0.30, 0.40, or 0.50
INIT_TYPE = 'dinov3'       # <-- change per run: 'dinov3' or 'coco'

# %%
# !pip install ultralytics -q
from ultralytics import YOLO
import torch, pandas as pd, os

def mem():
    return f"{torch.cuda.memory_allocated()/1e9:.2f} GB"
print("Baseline:", mem())
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 22.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 3.9 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Baseline: 0.00 GB

# %%
CONFIG = {
    'architecture': 'yolo12m',
    'partition_csv': '/kaggle/input/datasets/redwanahmed2025/groupj-partb-partition/partition.csv',
    'label_fraction': RHO,
    'seed': 42,
    'epochs': 50,
    'img_size': 640,
    'batch_size': 32,
    'lr': 1e-3,
}
print(CONFIG)
# Out:
# {'architecture': 'yolo12m', 'partition_csv': '/kaggle/input/datasets/redwanahmed2025/groupj-partb-partition/partition.csv', 'label_fraction': 0.3, 'seed': 42, 'epochs': 50, 'img_size': 640, 'batch_size': 32, 'lr': 0.001}

# %%
partition = pd.read_csv(CONFIG['partition_csv'])

def build_rho_subset(rho, partition_df):
    k = int(round(rho * 10))
    return partition_df[(partition_df['role'] == 'pool') & (partition_df['pool_fold'] < k)]

d_rho_df = build_rho_subset(RHO, partition)
print(f"D_{RHO} size:", len(d_rho_df))

test_val_ids = set(partition[partition['role'].isin(['test', 'val'])]['image_id'])
overlap = test_val_ids.intersection(set(d_rho_df['image_id']))
print("Overlap (must be 0):", len(overlap))
# Out:
# D_0.3 size: 3000
# Overlap (must be 0): 0

# %%
def build_yolo_split(df, split_name, base_dir='/kaggle/working/yolo_data'):
    img_dir = f'{base_dir}/{split_name}/images'
    lbl_dir = f'{base_dir}/{split_name}/labels'
    os.makedirs(img_dir, exist_ok=True)
    os.makedirs(lbl_dir, exist_ok=True)
    for _, row in df.iterrows():
        img_src, lbl_src = row['image_path'], row['label_path']
        img_dst = f"{img_dir}/{os.path.basename(img_src)}"
        lbl_dst = f"{lbl_dir}/{os.path.basename(lbl_src)}"
        if not os.path.exists(img_dst):
            os.symlink(img_src, img_dst)
        if not os.path.exists(lbl_dst) and os.path.exists(lbl_src):
            os.symlink(lbl_src, lbl_dst)
    return img_dir, lbl_dir

val_df = partition[partition['role'] == 'val']
test_df = partition[partition['role'] == 'test']
build_yolo_split(d_rho_df, 'train')
build_yolo_split(val_df, 'val')
build_yolo_split(test_df, 'test')

print("Train:", len(os.listdir('/kaggle/working/yolo_data/train/images')))
print("Val:", len(os.listdir('/kaggle/working/yolo_data/val/images')))
print("Test:", len(os.listdir('/kaggle/working/yolo_data/test/images')))

data_yaml_content = """
path: /kaggle/working/yolo_data
train: train/images
val: val/images
test: test/images
names:
  0: Cavities
  1: Damage
  2: Infection
  3: Wisdom
"""
with open('/kaggle/working/data.yaml', 'w') as f:
    f.write(data_yaml_content)
# Out:
# Train: 3000
# Val: 1000
# Test: 1000

# %%
if INIT_TYPE == 'dinov3':
    checkpoint_dir = '/kaggle/input/datasets/kanizmithila/groupj-partb-dinov3-checkpoint'  # adjust if path differs
    dinov3_state = torch.load(f'{checkpoint_dir}/dinov3_backbone.pt', map_location='cpu')

    class YOLOv12Backbone(torch.nn.Module):
        def __init__(self, full_model):
            super().__init__()
            self.layers = torch.nn.Sequential(*[full_model.model.model[i] for i in range(9)])
        def forward(self, x):
            return self.layers(x)

    fresh_model = YOLO('yolo12m.yaml')
    remapped_state = {k.replace('layers.', 'model.', 1): v for k, v in dinov3_state.items()}
    missing, unexpected = fresh_model.model.load_state_dict(remapped_state, strict=False)
    print(f"Unexpected keys (should be 0): {len(unexpected)}")
    fresh_model.save('/kaggle/working/model_initialized.pt')
    model = YOLO('/kaggle/working/model_initialized.pt')

elif INIT_TYPE == 'coco':
    model = YOLO('yolo12m.pt')  # standard COCO-pretrained weights

print(f"Model ready: {INIT_TYPE} @ rho={RHO}")
# Out:
# Unexpected keys (should be 0): 0
# Model ready: dinov3 @ rho=0.3

# %%
run_name = f'bonus_{INIT_TYPE}_rho{int(RHO*100)}'
results = model.train(
    data='/kaggle/working/data.yaml',
    epochs=CONFIG['epochs'], imgsz=CONFIG['img_size'], batch=CONFIG['batch_size'],
    lr0=CONFIG['lr'], seed=CONFIG['seed'],
    project='/kaggle/working/runs', name=run_name, exist_ok=True, patience=0,
)
# Out:
# Ultralytics 8.4.120 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/kaggle/working/model_initialized.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=bonus_dinov3_rho30, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=0, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/bonus_dinov3_rho30, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 17.2MB/s 0.0s
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 4]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1   1248768  ultralytics.nn.modules.block.A2C2f           [1024, 512, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1    378624  ultralytics.nn.modules.block.A2C2f           [1024, 256, 1, False, -1]
#  15                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1   1183232  ultralytics.nn.modules.block.A2C2f           [768, 512, 1, False, -1]
#  18                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  21        [14, 17, 20]  1   1414108  ultralytics.nn.modules.head.Detect           [4, 16, None, [256, 512, 512]]
# YOLO12m summary: 292 layers, 20,140,572 parameters, 20,140,556 gradients, 71.0 GFLOPs
#
# Transferred 745/751 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 69.7MB/s 0.1s
# AMP: checks passed ✅
# WARNING ⚠️ train: Slow image access detected (ping: 0.6±0.4 ms, read: 5.7±2.2 MB/s, size: 34.0 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# train: Scanning /kaggle/working/yolo_data/train/labels... 3000 images, 54 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 165.8it/s 18.1s
# train: New cache created: /kaggle/working/yolo_data/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 5.9±2.7 MB/s, size: 39.4 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /kaggle/working/yolo_data/val/labels... 1000 images, 6 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1000/1000 266.4it/s 3.8s
# val: New cache created: /kaggle/working/yolo_data/val/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 123 weight(decay=0.0), 130 weight(decay=0.0005), 129 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/bonus_dinov3_rho30/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/bonus_dinov3_rho30
# Starting training for 50 epochs...
# WARNING ⚠️ CUDA out of memory with batch=32. Reducing to batch=16 and retrying (1/3).
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 66.2±21.6 MB/s, size: 36.7 KB)
# train: Scanning /kaggle/working/yolo_data/train/labels.cache... 3000 images, 54 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 1.3Git/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.1±0.2 ms, read: 50.8±9.9 MB/s, size: 36.6 KB)
# val: Scanning /kaggle/working/yolo_data/val/labels.cache... 1000 images, 6 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1000/1000 45.6Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 123 weight(decay=0.0), 130 weight(decay=0.0005), 129 bias(decay=0.0)
# : 0% ──────────── 0/94  4.6s
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING ⚠️ CUDA backend memory error with batch=16. Reducing to batch=8 and retrying (2/3).
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 56.6±26.0 MB/s, size: 39.2 KB)
# train: Scanning /kaggle/working/yolo_data/train/labels.cache... 3000 images, 54 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3000/3000 1.4Git/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 61.5±9.3 MB/s, size: 37.4 KB)
# val: Scanning /kaggle/working/yolo_data/val/labels.cache... 1000 images, 6 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1000/1000 51.8Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 123 weight(decay=0.0), 130 weight(decay=0.0005), 129 bias(decay=0.0)
# : 0% ──────────── 0/188  10.3s
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      8.05G      3.791      4.532      3.244         41        640: 100% ━━━━━━━━━━━━ 375/375 2.3it/s 2:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.6s/it 25.5s
#                    all       1000       2470     0.0945       0.12     0.0154    0.00388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      5.98G      2.862      2.874      2.367         18        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.3s
#                    all       1000       2470      0.285      0.294       0.22      0.089
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50       6.1G        2.7       2.59      2.222         27        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.304      0.287      0.224     0.0839
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      5.98G       2.62      2.444      2.125         18        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.305      0.337      0.233      0.087
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      5.98G      2.531      2.342      2.063         42        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.353      0.382      0.329      0.136
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50       6.1G      2.468      2.257      2.004         40        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.9s
#                    all       1000       2470      0.258      0.167     0.0911     0.0269
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      5.98G      2.431      2.202      1.974         33        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.313      0.401      0.351      0.151
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      5.99G      2.404       2.16      1.952         31        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.316      0.391      0.331      0.141
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      5.98G       2.38      2.102      1.932         22        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.391      0.405      0.369      0.158
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      5.98G      2.346      2.071      1.904         16        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.3s
#                    all       1000       2470       0.33      0.396      0.343      0.149
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      5.98G      2.333      2.037      1.896         45        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.338      0.433       0.37      0.148
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      5.98G      2.308      2.036      1.871         47        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.383      0.458      0.374      0.153
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      5.98G       2.29      2.036      1.865         17        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.9s
#                    all       1000       2470      0.386      0.447      0.378      0.166
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50       6.1G      2.278       1.99      1.862         21        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.423      0.478      0.407      0.176
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      5.98G      2.265      1.946      1.853         29        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.424      0.467        0.4      0.176
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      5.99G      2.251      1.945      1.835         25        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.9s
#                    all       1000       2470      0.377      0.471      0.405      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      5.98G      2.252      1.953      1.826         27        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.381      0.468        0.4      0.177
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      5.98G      2.224      1.907      1.827         20        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.409      0.473       0.41      0.178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      5.98G      2.219      1.916      1.821          8        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.395      0.487       0.42      0.177
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      5.99G      2.198      1.898      1.796         23        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.391      0.494      0.413      0.182
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      5.98G        2.2      1.899      1.819         29        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.409      0.476      0.416      0.178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50       6.1G      2.186      1.893      1.798         25        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.411      0.476      0.403      0.174
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      5.98G      2.181      1.831       1.79         34        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.453      0.489      0.422      0.184
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      5.99G      2.177      1.835      1.779         18        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.413      0.492       0.42      0.182
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      5.98G      2.166      1.835      1.783         27        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470       0.41      0.525      0.425      0.185
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      5.98G      2.174      1.837      1.778         22        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.413      0.483       0.41      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      5.98G      2.132      1.822      1.763         34        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.409      0.507      0.434      0.194
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      5.99G      2.129      1.789      1.749         40        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.443      0.494       0.43       0.19
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      5.98G      2.139      1.817      1.766         24        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.391      0.514      0.425      0.191
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50       6.1G      2.114      1.789      1.747         36        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.432      0.508      0.432      0.194
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      5.98G      2.113      1.759      1.745         18        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.413      0.507      0.419      0.187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      5.99G      2.078      1.749      1.727         31        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.434      0.504      0.433      0.194
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      5.98G      2.082      1.757      1.732         12        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.9s
#                    all       1000       2470      0.454      0.501      0.447      0.196
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      5.98G      2.097      1.744      1.735         28        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.9s
#                    all       1000       2470      0.441      0.504       0.43      0.197
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      5.98G      2.087      1.719      1.714         23        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.435      0.528      0.444        0.2
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      5.98G      2.086      1.744      1.731         21        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.3s
#                    all       1000       2470      0.455      0.509       0.45      0.198
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      5.98G      2.044      1.693      1.704         10        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.438      0.534      0.451      0.199
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50       6.1G       2.05      1.714      1.715         28        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.9s
#                    all       1000       2470      0.454      0.519      0.444      0.199
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      5.98G      2.067      1.713      1.721         17        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.449      0.511       0.45      0.204
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      5.98G      2.042      1.697        1.7         46        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.458      0.514      0.448        0.2
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      5.98G      1.999      1.667      1.811         17        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.443      0.528      0.457      0.206
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      5.98G      1.984      1.639      1.795         14        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.482      0.522      0.457      0.207
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      5.98G      1.985      1.646      1.786         13        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.477      0.528      0.462      0.206
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      5.98G      1.968      1.622      1.781         17        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.478      0.518      0.464      0.208
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      5.98G      1.966      1.605      1.775         24        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.469      0.528      0.469      0.209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50       6.1G       1.95      1.601       1.77         28        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.465      0.528      0.463      0.209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      5.98G      1.948      1.598      1.776         18        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.477      0.531      0.469      0.211
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      5.99G       1.92      1.568      1.753         15        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.473      0.538      0.469      0.213
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      5.98G      1.923       1.57      1.758         17        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.467      0.533      0.469      0.214
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      5.99G       1.91      1.559      1.744         16        640: 100% ━━━━━━━━━━━━ 375/375 2.4it/s 2:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470       0.47      0.536      0.472      0.214
#
# 50 epochs completed in 2.468 hours.
# Optimizer stripped from /kaggle/working/runs/bonus_dinov3_rho30/weights/last.pt, 40.8MB
# Optimizer stripped from /kaggle/working/runs/bonus_dinov3_rho30/weights/best.pt, 40.8MB
#
# Validating /kaggle/working/runs/bonus_dinov3_rho30/weights/best.pt...
# Ultralytics 8.4.120 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLO12m summary (fused): 169 layers, 20,107,996 parameters, 0 gradients, 70.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.4s
#                    all       1000       2470      0.466      0.533      0.469      0.214
#               Cavities        315        657      0.363      0.487      0.362      0.136
#                 Damage        354       1094      0.385      0.422      0.336      0.121
#              Infection        252        357      0.381      0.272      0.259     0.0801
#                 Wisdom        238        362      0.737       0.95      0.917       0.52
# Speed: 0.2ms preprocess, 16.5ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /kaggle/working/runs/bonus_dinov3_rho30

# %%
best_model = YOLO(f'/kaggle/working/runs/{run_name}/weights/best.pt')
test_metrics = best_model.val(
    data='/kaggle/working/data.yaml', split='test',
    imgsz=CONFIG['img_size'], batch=CONFIG['batch_size'],
    project='/kaggle/working/runs', name=f'{run_name}_test_eval', exist_ok=True,
)
print(f"\n=== {INIT_TYPE.upper()} @ rho={RHO} — TEST SET ===")
print(f"mAP50: {test_metrics.box.map50:.4f} | mAP50-95: {test_metrics.box.map:.4f}")
print(f"Precision: {test_metrics.box.mp:.4f} | Recall: {test_metrics.box.mr:.4f}")
# Out:
# Ultralytics 8.4.120 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLO12m summary (fused): 169 layers, 20,107,996 parameters, 0 gradients, 70.4 GFLOPs
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 8.0±1.7 MB/s, size: 39.3 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /kaggle/working/yolo_data/test/labels... 1000 images, 31 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1000/1000 323.8it/s 3.1s
# val: New cache created: /kaggle/working/yolo_data/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 1.4s/it 44.0s
#                    all       1000       2456      0.487      0.525      0.483      0.213
#               Cavities        315        662      0.425      0.498      0.406      0.148
#                 Damage        354       1060      0.403      0.394      0.361      0.123
#              Infection        252        376      0.392      0.274      0.254      0.089
#                 Wisdom        238        358      0.728      0.933      0.913      0.493
# Speed: 1.4ms preprocess, 39.1ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /kaggle/working/runs/bonus_dinov3_rho30_test_eval
#
# === DINOV3 @ rho=0.3 — TEST SET ===
# mAP50: 0.4834 | mAP50-95: 0.2131
# Precision: 0.4870 | Recall: 0.5249
