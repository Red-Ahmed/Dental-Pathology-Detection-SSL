# %%
RHO = 0.40                # change per notebook: 0.40 or 0.50
INIT_TYPE = 'dinov3'      # change per notebook: 'dinov3' or 'coco'

# %%
# !pip install ultralytics -q
from ultralytics import YOLO
import torch, pandas as pd, os

def mem():
    return f"{torch.cuda.memory_allocated()/1e9:.2f} GB"
print("Baseline:", mem())
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 44.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 4.2 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Baseline: 0.00 GB

# %%
CONFIG = {
    'architecture': 'yolo12m',
    'partition_csv': '/kaggle/input/datasets/redwanahmed2025/groupj-partb-partition/partition.csv',
    'label_fraction': RHO,
    'seed': 42, 'epochs': 50, 'img_size': 640, 'batch_size': 32, 'lr': 1e-3,
}
print(CONFIG)
# Out:
# {'architecture': 'yolo12m', 'partition_csv': '/kaggle/input/datasets/redwanahmed2025/groupj-partb-partition/partition.csv', 'label_fraction': 0.4, 'seed': 42, 'epochs': 50, 'img_size': 640, 'batch_size': 32, 'lr': 0.001}

# %%
partition = pd.read_csv(CONFIG['partition_csv'])

def build_rho_subset(rho, partition_df):
    k = int(round(rho * 10))
    return partition_df[(partition_df['role'] == 'pool') & (partition_df['pool_fold'] < k)]

d_rho_df = build_rho_subset(RHO, partition)
print(f"D_{RHO} size:", len(d_rho_df))

test_val_ids = set(partition[partition['role'].isin(['test', 'val'])]['image_id'])
overlap = test_val_ids.intersection(set(d_rho_df['image_id']))
print("Overlap (must be 0):", len(overlap))
# Out:
# D_0.4 size: 4000
# Overlap (must be 0): 0

# %%
def build_yolo_split(df, split_name, base_dir='/kaggle/working/yolo_data'):
    img_dir = f'{base_dir}/{split_name}/images'
    lbl_dir = f'{base_dir}/{split_name}/labels'
    os.makedirs(img_dir, exist_ok=True)
    os.makedirs(lbl_dir, exist_ok=True)
    for _, row in df.iterrows():
        img_src, lbl_src = row['image_path'], row['label_path']
        img_dst = f"{img_dir}/{os.path.basename(img_src)}"
        lbl_dst = f"{lbl_dir}/{os.path.basename(lbl_src)}"
        if not os.path.exists(img_dst):
            os.symlink(img_src, img_dst)
        if not os.path.exists(lbl_dst) and os.path.exists(lbl_src):
            os.symlink(lbl_src, lbl_dst)
    return img_dir, lbl_dir

val_df = partition[partition['role'] == 'val']
test_df = partition[partition['role'] == 'test']
build_yolo_split(d_rho_df, 'train')
build_yolo_split(val_df, 'val')
build_yolo_split(test_df, 'test')

print("Train:", len(os.listdir('/kaggle/working/yolo_data/train/images')))
print("Val:", len(os.listdir('/kaggle/working/yolo_data/val/images')))
print("Test:", len(os.listdir('/kaggle/working/yolo_data/test/images')))

data_yaml_content = """
path: /kaggle/working/yolo_data
train: train/images
val: val/images
test: test/images
names:
  0: Cavities
  1: Damage
  2: Infection
  3: Wisdom
"""
with open('/kaggle/working/data.yaml', 'w') as f:
    f.write(data_yaml_content)
# Out:
# Train: 4000
# Val: 1000
# Test: 1000

# %%
if INIT_TYPE == 'dinov3':
    checkpoint_dir = '/kaggle/input/datasets/kanizmithila/groupj-partb-dinov3-checkpoint'
    dinov3_state = torch.load(f'{checkpoint_dir}/dinov3_backbone.pt', map_location='cpu')

    class YOLOv12Backbone(torch.nn.Module):
        def __init__(self, full_model):
            super().__init__()
            self.layers = torch.nn.Sequential(*[full_model.model.model[i] for i in range(9)])
        def forward(self, x):
            return self.layers(x)

    fresh_model = YOLO('yolo12m.yaml')
    remapped_state = {k.replace('layers.', 'model.', 1): v for k, v in dinov3_state.items()}
    missing, unexpected = fresh_model.model.load_state_dict(remapped_state, strict=False)
    print(f"Unexpected keys (should be 0): {len(unexpected)}")
    fresh_model.save('/kaggle/working/model_initialized.pt')
    model = YOLO('/kaggle/working/model_initialized.pt')

elif INIT_TYPE == 'coco':
    model = YOLO('yolo12m.pt')

print(f"Model ready: {INIT_TYPE} @ rho={RHO}")
# Out:
# Unexpected keys (should be 0): 0
# Model ready: dinov3 @ rho=0.4

# %%
run_name = f'bonus_{INIT_TYPE}_rho{int(RHO*100)}'
results = model.train(
    data='/kaggle/working/data.yaml',
    epochs=CONFIG['epochs'], imgsz=CONFIG['img_size'], batch=CONFIG['batch_size'],
    lr0=CONFIG['lr'], seed=CONFIG['seed'],
    project='/kaggle/working/runs', name=run_name, exist_ok=True, patience=0,
)
# Out:
# Ultralytics 8.4.120 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/kaggle/working/model_initialized.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=bonus_dinov3_rho40, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=0, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/bonus_dinov3_rho40, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 71.8MB/s 0.0s
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 4]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1   1248768  ultralytics.nn.modules.block.A2C2f           [1024, 512, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1    378624  ultralytics.nn.modules.block.A2C2f           [1024, 256, 1, False, -1]
#  15                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1   1183232  ultralytics.nn.modules.block.A2C2f           [768, 512, 1, False, -1]
#  18                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  21        [14, 17, 20]  1   1414108  ultralytics.nn.modules.head.Detect           [4, 16, None, [256, 512, 512]]
# YOLO12m summary: 292 layers, 20,140,572 parameters, 20,140,556 gradients, 71.0 GFLOPs
#
# Transferred 745/751 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 225.2MB/s 0.0s
# AMP: checks passed ✅
# WARNING ⚠️ train: Slow image access detected (ping: 0.7±0.4 ms, read: 5.2±0.2 MB/s, size: 35.9 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# train: Scanning /kaggle/working/yolo_data/train/labels... 4000 images, 81 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4000/4000 203.9it/s 19.6s
# train: New cache created: /kaggle/working/yolo_data/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 6.5±1.2 MB/s, size: 41.4 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /kaggle/working/yolo_data/val/labels... 1000 images, 6 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1000/1000 223.8it/s 4.5s
# val: New cache created: /kaggle/working/yolo_data/val/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 123 weight(decay=0.0), 130 weight(decay=0.0005), 129 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/bonus_dinov3_rho40/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/bonus_dinov3_rho40
# Starting training for 50 epochs...
# WARNING ⚠️ CUDA out of memory with batch=32. Reducing to batch=16 and retrying (1/3).
# WARNING ⚠️ train: Slow image access detected (ping: 0.0±0.0 ms, read: 42.1±6.9 MB/s, size: 38.5 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# train: Scanning /kaggle/working/yolo_data/train/labels.cache... 4000 images, 81 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4000/4000 1.4Git/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 40.1±3.3 MB/s, size: 35.2 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /kaggle/working/yolo_data/val/labels.cache... 1000 images, 6 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1000/1000 62.6Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 123 weight(decay=0.0), 130 weight(decay=0.0005), 129 bias(decay=0.0)
# : 0% ──────────── 0/125  6.3s
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING ⚠️ CUDA backend memory error with batch=16. Reducing to batch=8 and retrying (2/3).
# WARNING ⚠️ train: Slow image access detected (ping: 0.0±0.0 ms, read: 39.2±11.7 MB/s, size: 34.1 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# train: Scanning /kaggle/working/yolo_data/train/labels.cache... 4000 images, 81 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4000/4000 1.4Git/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 40.4±1.8 MB/s, size: 36.7 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /kaggle/working/yolo_data/val/labels.cache... 1000 images, 6 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1000/1000 66.6Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 123 weight(decay=0.0), 130 weight(decay=0.0005), 129 bias(decay=0.0)
# : 0% ──────────── 0/250  14.3s
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      8.06G       3.62      4.312      3.064         27        640: 100% ━━━━━━━━━━━━ 500/500 2.3it/s 3:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.6s/it 25.8s
#                    all       1000       2470      0.312      0.202      0.152     0.0546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      5.98G      2.799      2.719      2.302         30        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.308      0.321      0.265      0.105
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      5.98G      2.648      2.498      2.144         29        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.236      0.342      0.272      0.101
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      5.99G      2.527      2.331      2.029         42        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.4s
#                    all       1000       2470      0.353      0.384       0.33      0.141
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      5.99G      2.449      2.229      1.982         27        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470       0.31       0.41      0.356      0.149
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      5.98G      2.399       2.16      1.941         26        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.323       0.41      0.342       0.14
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      5.99G      2.372      2.137      1.906         31        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.364      0.412      0.347      0.144
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      5.98G      2.344      2.098      1.905         30        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.387       0.42      0.368      0.151
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      5.99G      2.307       2.03      1.883         30        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.377      0.461      0.386      0.165
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      5.98G      2.314      2.024      1.879         25        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.355      0.452      0.372       0.16
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      5.99G      2.274      1.974      1.855         31        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.402       0.41      0.343      0.134
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      5.99G       2.27      1.976      1.845         44        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.403      0.452      0.381      0.166
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      5.99G      2.264      1.953      1.836         22        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.399      0.419      0.364      0.152
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      5.99G      2.236      1.935      1.828         23        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.405      0.474      0.401      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      5.98G      2.226      1.927      1.806         30        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.3s
#                    all       1000       2470      0.386       0.47      0.406      0.177
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      5.99G      2.225      1.914      1.809         18        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.393      0.458      0.392       0.17
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      5.98G      2.224       1.91      1.803         44        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.397      0.487      0.407       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      5.98G      2.185      1.883       1.79         34        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470       0.44      0.481      0.421      0.188
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      5.98G      2.173      1.853      1.782         23        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.399      0.475      0.417      0.187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      5.98G       2.19      1.865      1.775         32        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.395      0.497       0.41       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      5.99G      2.182       1.86      1.784         35        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.434      0.505      0.439      0.194
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      5.99G      2.163      1.845       1.77         25        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.3s
#                    all       1000       2470      0.415      0.491      0.415      0.186
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      5.98G      2.152      1.827      1.772         15        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470       0.42      0.509      0.434      0.193
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      5.99G      2.133      1.811      1.759         17        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.418      0.496      0.426      0.189
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      5.98G      2.139      1.789      1.757         15        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.423      0.522      0.439      0.193
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      5.98G      2.106      1.758      1.737         22        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.4s
#                    all       1000       2470      0.421      0.506       0.43      0.189
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      5.98G       2.11      1.768      1.741         21        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.455      0.527      0.448      0.198
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      5.99G      2.106      1.763      1.736         21        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.443        0.5       0.43      0.194
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      5.99G      2.098      1.755      1.733         26        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.3s
#                    all       1000       2470      0.455       0.52      0.441      0.195
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      5.99G      2.104      1.745      1.733         27        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.425      0.532      0.444      0.202
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      5.99G      2.082      1.743      1.719         29        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.445      0.516      0.454      0.207
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      5.98G      2.091      1.753      1.735         19        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.437       0.52      0.441        0.2
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      5.99G       2.07      1.715      1.722         29        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.442       0.52      0.445        0.2
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      5.98G       2.06      1.725       1.72         23        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.432      0.529      0.449      0.201
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      5.99G      2.058      1.714      1.702         30        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.449      0.521      0.455      0.205
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      5.98G      2.045        1.7       1.68         28        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.444      0.534      0.452      0.206
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      5.98G      2.038      1.671      1.701         35        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.0s
#                    all       1000       2470      0.447      0.524       0.45      0.206
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      5.98G      2.037      1.674      1.689         44        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.445      0.524       0.46      0.209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      5.98G      2.029      1.665      1.691         22        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.466      0.537      0.463      0.211
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      5.99G      2.009      1.652      1.674         31        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.3s
#                    all       1000       2470      0.464      0.538      0.459      0.207
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      5.99G      1.991      1.634      1.783         12        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.462      0.523      0.465      0.211
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      5.99G      1.981      1.628       1.78         23        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470       0.48      0.539      0.476      0.215
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      5.99G      1.963      1.613      1.778         21        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.479      0.531      0.471      0.214
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      5.99G      1.956      1.582      1.756         26        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.477      0.558      0.484       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      5.98G      1.947      1.591      1.763         12        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.3s
#                    all       1000       2470      0.484      0.527      0.484       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      5.99G      1.935      1.579      1.767         13        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.488      0.537      0.482      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      5.98G      1.916      1.562       1.75         18        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.489      0.545       0.49      0.222
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      5.99G      1.912       1.56      1.742         25        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.492      0.529      0.489      0.221
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      5.98G      1.915      1.547      1.744         19        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.493       0.55      0.492      0.224
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      5.99G      1.909       1.55       1.74         20        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.2s
#                    all       1000       2470      0.497      0.537      0.492      0.225
#
# 50 epochs completed in 3.185 hours.
# Optimizer stripped from /kaggle/working/runs/bonus_dinov3_rho40/weights/last.pt, 40.8MB
# Optimizer stripped from /kaggle/working/runs/bonus_dinov3_rho40/weights/best.pt, 40.8MB
#
# Validating /kaggle/working/runs/bonus_dinov3_rho40/weights/best.pt...
# Ultralytics 8.4.120 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLO12m summary (fused): 169 layers, 20,107,996 parameters, 0 gradients, 70.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 21.1s
#                    all       1000       2470      0.498      0.537      0.492      0.225
#               Cavities        315        657      0.394      0.466      0.384      0.146
#                 Damage        354       1094       0.43      0.423      0.371      0.135
#              Infection        252        357      0.417      0.308      0.284     0.0935
#                 Wisdom        238        362       0.75       0.95      0.927      0.525
# Speed: 0.2ms preprocess, 16.7ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /kaggle/working/runs/bonus_dinov3_rho40

# %%
best_model = YOLO(f'/kaggle/working/runs/{run_name}/weights/best.pt')
test_metrics = best_model.val(
    data='/kaggle/working/data.yaml', split='test',
    imgsz=CONFIG['img_size'], batch=CONFIG['batch_size'],
    project='/kaggle/working/runs', name=f'{run_name}_test_eval', exist_ok=True,
)
print(f"\n=== {INIT_TYPE.upper()} @ rho={RHO} — TEST SET ===")
print(f"mAP50: {test_metrics.box.map50:.4f} | mAP50-95: {test_metrics.box.map:.4f}")
print(f"Precision: {test_metrics.box.mp:.4f} | Recall: {test_metrics.box.mr:.4f}")
# Out:
# Ultralytics 8.4.120 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLO12m summary (fused): 169 layers, 20,107,996 parameters, 0 gradients, 70.4 GFLOPs
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 4.8±1.1 MB/s, size: 37.9 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /kaggle/working/yolo_data/test/labels... 1000 images, 31 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1000/1000 233.6it/s 4.3s
# val: New cache created: /kaggle/working/yolo_data/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 1.4s/it 45.3s
#                    all       1000       2456      0.489      0.541      0.498      0.216
#               Cavities        315        662       0.43      0.485      0.415      0.152
#                 Damage        354       1060       0.42      0.406       0.38      0.133
#              Infection        252        376      0.375      0.326      0.281     0.0854
#                 Wisdom        238        358      0.732      0.947      0.915      0.492
# Speed: 1.4ms preprocess, 40.3ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to /kaggle/working/runs/bonus_dinov3_rho40_test_eval
#
# === DINOV3 @ rho=0.4 — TEST SET ===
# mAP50: 0.4979 | mAP50-95: 0.2159
# Precision: 0.4894 | Recall: 0.5409
