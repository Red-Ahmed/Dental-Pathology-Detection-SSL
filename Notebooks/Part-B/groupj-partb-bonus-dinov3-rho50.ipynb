# %%
RHO = 0.50                # change per notebook: 0.40 or 0.50
INIT_TYPE = 'dinov3'      # change per notebook: 'dinov3' or 'coco'

# %%
# !pip install ultralytics -q
from ultralytics import YOLO
import torch, pandas as pd, os

def mem():
    return f"{torch.cuda.memory_allocated()/1e9:.2f} GB"
print("Baseline:", mem())
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 30.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 4.4 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Baseline: 0.00 GB

# %%
CONFIG = {
    'architecture': 'yolo12m',
    'partition_csv': '/kaggle/input/datasets/redwanahmed2025/groupj-partb-partition/partition.csv',
    'label_fraction': RHO,
    'seed': 42, 'epochs': 50, 'img_size': 640, 'batch_size': 32, 'lr': 1e-3,
}
print(CONFIG)
# Out:
# {'architecture': 'yolo12m', 'partition_csv': '/kaggle/input/datasets/redwanahmed2025/groupj-partb-partition/partition.csv', 'label_fraction': 0.5, 'seed': 42, 'epochs': 50, 'img_size': 640, 'batch_size': 32, 'lr': 0.001}

# %%
partition = pd.read_csv(CONFIG['partition_csv'])

def build_rho_subset(rho, partition_df):
    k = int(round(rho * 10))
    return partition_df[(partition_df['role'] == 'pool') & (partition_df['pool_fold'] < k)]

d_rho_df = build_rho_subset(RHO, partition)
print(f"D_{RHO} size:", len(d_rho_df))

test_val_ids = set(partition[partition['role'].isin(['test', 'val'])]['image_id'])
overlap = test_val_ids.intersection(set(d_rho_df['image_id']))
print("Overlap (must be 0):", len(overlap))
# Out:
# D_0.5 size: 5000
# Overlap (must be 0): 0

# %%
def build_yolo_split(df, split_name, base_dir='/kaggle/working/yolo_data'):
    img_dir = f'{base_dir}/{split_name}/images'
    lbl_dir = f'{base_dir}/{split_name}/labels'
    os.makedirs(img_dir, exist_ok=True)
    os.makedirs(lbl_dir, exist_ok=True)
    for _, row in df.iterrows():
        img_src, lbl_src = row['image_path'], row['label_path']
        img_dst = f"{img_dir}/{os.path.basename(img_src)}"
        lbl_dst = f"{lbl_dir}/{os.path.basename(lbl_src)}"
        if not os.path.exists(img_dst):
            os.symlink(img_src, img_dst)
        if not os.path.exists(lbl_dst) and os.path.exists(lbl_src):
            os.symlink(lbl_src, lbl_dst)
    return img_dir, lbl_dir

val_df = partition[partition['role'] == 'val']
test_df = partition[partition['role'] == 'test']
build_yolo_split(d_rho_df, 'train')
build_yolo_split(val_df, 'val')
build_yolo_split(test_df, 'test')

print("Train:", len(os.listdir('/kaggle/working/yolo_data/train/images')))
print("Val:", len(os.listdir('/kaggle/working/yolo_data/val/images')))
print("Test:", len(os.listdir('/kaggle/working/yolo_data/test/images')))

data_yaml_content = """
path: /kaggle/working/yolo_data
train: train/images
val: val/images
test: test/images
names:
  0: Cavities
  1: Damage
  2: Infection
  3: Wisdom
"""
with open('/kaggle/working/data.yaml', 'w') as f:
    f.write(data_yaml_content)
# Out:
# Train: 5000
# Val: 1000
# Test: 1000

# %%
if INIT_TYPE == 'dinov3':
    checkpoint_dir = '/kaggle/input/datasets/kanizmithila/groupj-partb-dinov3-checkpoint'
    dinov3_state = torch.load(f'{checkpoint_dir}/dinov3_backbone.pt', map_location='cpu')

    class YOLOv12Backbone(torch.nn.Module):
        def __init__(self, full_model):
            super().__init__()
            self.layers = torch.nn.Sequential(*[full_model.model.model[i] for i in range(9)])
        def forward(self, x):
            return self.layers(x)

    fresh_model = YOLO('yolo12m.yaml')
    remapped_state = {k.replace('layers.', 'model.', 1): v for k, v in dinov3_state.items()}
    missing, unexpected = fresh_model.model.load_state_dict(remapped_state, strict=False)
    print(f"Unexpected keys (should be 0): {len(unexpected)}")
    fresh_model.save('/kaggle/working/model_initialized.pt')
    model = YOLO('/kaggle/working/model_initialized.pt')

elif INIT_TYPE == 'coco':
    model = YOLO('yolo12m.pt')

print(f"Model ready: {INIT_TYPE} @ rho={RHO}")
# Out:
# Unexpected keys (should be 0): 0
# Model ready: dinov3 @ rho=0.5

# %%
run_name = f'bonus_{INIT_TYPE}_rho{int(RHO*100)}'
results = model.train(
    data='/kaggle/working/data.yaml',
    epochs=CONFIG['epochs'], imgsz=CONFIG['img_size'], batch=CONFIG['batch_size'],
    lr0=CONFIG['lr'], seed=CONFIG['seed'],
    project='/kaggle/working/runs', name=run_name, exist_ok=True, patience=0,
)
# Out:
# Ultralytics 8.4.120 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/kaggle/working/model_initialized.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=bonus_dinov3_rho50, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=0, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/bonus_dinov3_rho50, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 24.2MB/s 0.0s
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 4]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1   1248768  ultralytics.nn.modules.block.A2C2f           [1024, 512, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1    378624  ultralytics.nn.modules.block.A2C2f           [1024, 256, 1, False, -1]
#  15                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1   1183232  ultralytics.nn.modules.block.A2C2f           [768, 512, 1, False, -1]
#  18                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  21        [14, 17, 20]  1   1414108  ultralytics.nn.modules.head.Detect           [4, 16, None, [256, 512, 512]]
# YOLO12m summary: 292 layers, 20,140,572 parameters, 20,140,556 gradients, 71.0 GFLOPs
#
# Transferred 745/751 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 100.4MB/s 0.1s
# AMP: checks passed ✅
# WARNING ⚠️ train: Slow image access detected (ping: 0.4±0.4 ms, read: 12.2±1.6 MB/s, size: 38.9 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# train: Scanning /kaggle/working/yolo_data/train/labels... 5000 images, 89 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 5000/5000 372.4it/s 13.4s
# train: New cache created: /kaggle/working/yolo_data/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 11.9±2.2 MB/s, size: 39.4 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /kaggle/working/yolo_data/val/labels... 1000 images, 6 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1000/1000 364.0it/s 2.7s
# val: New cache created: /kaggle/working/yolo_data/val/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 123 weight(decay=0.0), 130 weight(decay=0.0005), 129 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/bonus_dinov3_rho50/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/bonus_dinov3_rho50
# Starting training for 50 epochs...
# WARNING ⚠️ CUDA out of memory with batch=32. Reducing to batch=16 and retrying (1/3).
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 59.0±8.5 MB/s, size: 36.9 KB)
# train: Scanning /kaggle/working/yolo_data/train/labels.cache... 5000 images, 89 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 5000/5000 1.7Git/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 36.7±25.6 MB/s, size: 36.6 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /kaggle/working/yolo_data/val/labels.cache... 1000 images, 6 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1000/1000 73.6Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 123 weight(decay=0.0), 130 weight(decay=0.0005), 129 bias(decay=0.0)
# : 0% ──────────── 0/157  8.6s
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING ⚠️ CUDA backend memory error with batch=16. Reducing to batch=8 and retrying (2/3).
# WARNING ⚠️ train: Slow image access detected (ping: 0.0±0.0 ms, read: 42.5±15.2 MB/s, size: 37.1 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# train: Scanning /kaggle/working/yolo_data/train/labels.cache... 5000 images, 89 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 5000/5000 2.1Git/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# WARNING ⚠️ val: Slow image access detected (ping: 0.5±1.1 ms, read: 23.8±14.1 MB/s, size: 36.7 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /kaggle/working/yolo_data/val/labels.cache... 1000 images, 6 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1000/1000 89.2Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 123 weight(decay=0.0), 130 weight(decay=0.0005), 129 bias(decay=0.0)
# : 0% ──────────── 0/313  10.2s
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      8.06G      3.489       4.06      2.939         28        640: 100% ━━━━━━━━━━━━ 625/625 2.2it/s 4:45
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.7s/it 27.2s
#                    all       1000       2470      0.865      0.115      0.128      0.043
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      5.98G      2.704      2.588      2.206         23        640: 100% ━━━━━━━━━━━━ 625/625 2.2it/s 4:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.9s
#                    all       1000       2470      0.317      0.277      0.278      0.112
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50       6.1G      2.545      2.353      2.066         31        640: 100% ━━━━━━━━━━━━ 625/625 2.2it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.8s
#                    all       1000       2470      0.313      0.369      0.288      0.121
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      5.98G      2.475      2.254      2.012         27        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.7s
#                    all       1000       2470      0.316      0.386      0.313      0.131
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      5.99G      2.418      2.157      1.961         37        640: 100% ━━━━━━━━━━━━ 625/625 2.2it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.7s
#                    all       1000       2470      0.344      0.417      0.351      0.155
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      5.98G      2.376      2.142      1.928         22        640: 100% ━━━━━━━━━━━━ 625/625 2.2it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.8s
#                    all       1000       2470       0.36       0.44      0.371      0.151
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      5.99G      2.337      2.094      1.897         20        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.7s
#                    all       1000       2470      0.338      0.434      0.361      0.146
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      5.98G      2.315      2.052      1.877         21        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.8s
#                    all       1000       2470      0.386      0.434      0.378      0.163
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      5.99G      2.308      2.026      1.869         30        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.7s
#                    all       1000       2470      0.344      0.463      0.383      0.157
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      5.98G      2.265      1.988      1.834         16        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.8s
#                    all       1000       2470      0.411      0.431      0.369      0.158
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50       6.1G      2.267      1.974      1.846         20        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.8s
#                    all       1000       2470      0.432      0.451       0.38      0.163
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      5.98G      2.232      1.946      1.813         31        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.8s
#                    all       1000       2470      0.416      0.461      0.398      0.176
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      5.99G      2.207      1.922      1.807         16        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.8s
#                    all       1000       2470      0.386      0.483      0.406       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      5.98G       2.21      1.925      1.817         21        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.8s
#                    all       1000       2470      0.426      0.456      0.407      0.178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      5.98G      2.203      1.885      1.796         41        640: 100% ━━━━━━━━━━━━ 625/625 2.2it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.8s
#                    all       1000       2470      0.416      0.478      0.413      0.184
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      5.98G      2.186      1.881      1.777         28        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.6s
#                    all       1000       2470      0.421      0.486      0.414      0.182
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      5.99G      2.177      1.877      1.793         22        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.7s
#                    all       1000       2470      0.432      0.489      0.419      0.184
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      5.98G      2.161      1.855      1.785         41        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.7s
#                    all       1000       2470      0.434      0.499      0.428      0.189
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50       6.1G      2.162      1.835      1.773         25        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.8s
#                    all       1000       2470      0.406      0.504      0.426      0.189
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      5.98G      2.161      1.848      1.779         20        640: 100% ━━━━━━━━━━━━ 625/625 2.2it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.6s
#                    all       1000       2470      0.436      0.475      0.424      0.186
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      5.99G      2.154      1.818      1.757         28        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.8s
#                    all       1000       2470      0.401      0.486      0.429      0.192
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      5.98G      2.136       1.82      1.759         25        640: 100% ━━━━━━━━━━━━ 625/625 2.2it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.9s
#                    all       1000       2470      0.435      0.509      0.445        0.2
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      5.98G      2.119        1.8      1.755         33        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.6s
#                    all       1000       2470      0.438      0.498      0.433      0.197
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      5.98G      2.109      1.761      1.746         41        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.6s
#                    all       1000       2470      0.451      0.529      0.448      0.201
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      5.98G      2.098      1.763      1.736         23        640: 100% ━━━━━━━━━━━━ 625/625 2.2it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.8s
#                    all       1000       2470      0.466      0.501      0.441      0.199
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      5.98G      2.098      1.766      1.733         22        640: 100% ━━━━━━━━━━━━ 625/625 2.2it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.7s
#                    all       1000       2470      0.457      0.511       0.45      0.201
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50       6.1G      2.115      1.786      1.757         30        640: 100% ━━━━━━━━━━━━ 625/625 2.2it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.7s
#                    all       1000       2470      0.435      0.503       0.44      0.195
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      5.98G      2.099       1.77      1.739         46        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.7s
#                    all       1000       2470      0.442      0.517      0.452      0.202
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      5.98G      2.081      1.751      1.717         41        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.7s
#                    all       1000       2470      0.452      0.498      0.448      0.202
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      5.98G      2.079      1.755       1.72         14        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.6s
#                    all       1000       2470      0.452      0.512      0.453      0.205
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      5.98G      2.066      1.738      1.714         39        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.8s
#                    all       1000       2470       0.45       0.52      0.444      0.205
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      5.98G      2.056      1.689      1.714         24        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.7s
#                    all       1000       2470      0.443      0.532      0.458      0.209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      5.99G      2.051      1.698      1.709         29        640: 100% ━━━━━━━━━━━━ 625/625 2.2it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.6s
#                    all       1000       2470      0.477      0.541      0.475      0.212
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      5.98G      2.051      1.701      1.707         24        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.7s
#                    all       1000       2470       0.46      0.536       0.47      0.213
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50       6.1G      2.048      1.702      1.698         22        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.6s
#                    all       1000       2470      0.457      0.519      0.468      0.213
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      5.99G      2.034      1.683      1.686         24        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.6s
#                    all       1000       2470      0.448      0.541       0.46      0.213
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      5.99G      2.016      1.669      1.685         19        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.8s
#                    all       1000       2470      0.465      0.533       0.48      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      5.98G       2.02      1.653      1.685         32        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.6s
#                    all       1000       2470      0.451      0.538      0.477      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      5.98G      2.011      1.657      1.675         22        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.8s
#                    all       1000       2470      0.459       0.54      0.468      0.216
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      5.98G      2.005      1.626      1.675         40        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.6s
#                    all       1000       2470      0.476      0.543      0.481       0.22
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      5.99G      1.974      1.609      1.776         26        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.7s
#                    all       1000       2470      0.468      0.537      0.487      0.222
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      5.98G      1.961      1.599      1.773         17        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.7s
#                    all       1000       2470       0.46      0.536       0.48      0.222
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50       6.1G      1.956      1.585      1.766         21        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.6s
#                    all       1000       2470      0.483      0.543      0.487      0.223
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      5.98G      1.935      1.574      1.756         22        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.6s
#                    all       1000       2470        0.5      0.539       0.49      0.224
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      5.98G      1.928       1.56      1.746         34        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.6s
#                    all       1000       2470      0.484      0.547      0.497      0.226
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      5.98G      1.916      1.557      1.741         21        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.6s
#                    all       1000       2470      0.486      0.555      0.497      0.228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      5.98G      1.918      1.539      1.746         27        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.8s
#                    all       1000       2470      0.487      0.555      0.501       0.23
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      5.98G      1.909      1.542      1.741         22        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.5s
#                    all       1000       2470      0.491      0.559      0.494      0.229
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      5.98G      1.895      1.526      1.741         12        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.5s
#                    all       1000       2470      0.498      0.556      0.501      0.232
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      5.98G      1.894      1.523      1.726         17        640: 100% ━━━━━━━━━━━━ 625/625 2.3it/s 4:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.7s
#                    all       1000       2470      0.495      0.555      0.502      0.233
#
# 50 epochs completed in 4.194 hours.
# Optimizer stripped from /kaggle/working/runs/bonus_dinov3_rho50/weights/last.pt, 40.8MB
# Optimizer stripped from /kaggle/working/runs/bonus_dinov3_rho50/weights/best.pt, 40.8MB
#
# Validating /kaggle/working/runs/bonus_dinov3_rho50/weights/best.pt...
# Ultralytics 8.4.120 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLO12m summary (fused): 169 layers, 20,107,996 parameters, 0 gradients, 70.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.4s/it 22.3s
#                    all       1000       2470      0.494      0.555      0.503      0.233
#               Cavities        315        657      0.399      0.472      0.392      0.152
#                 Damage        354       1094      0.439      0.442      0.394      0.148
#              Infection        252        357      0.401      0.347      0.295        0.1
#                 Wisdom        238        362      0.739      0.959       0.93      0.532
# Speed: 0.2ms preprocess, 18.1ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /kaggle/working/runs/bonus_dinov3_rho50

# %%
best_model = YOLO(f'/kaggle/working/runs/{run_name}/weights/best.pt')
test_metrics = best_model.val(
    data='/kaggle/working/data.yaml', split='test',
    imgsz=CONFIG['img_size'], batch=CONFIG['batch_size'],
    project='/kaggle/working/runs', name=f'{run_name}_test_eval', exist_ok=True,
)
print(f"\n=== {INIT_TYPE.upper()} @ rho={RHO} — TEST SET ===")
print(f"mAP50: {test_metrics.box.map50:.4f} | mAP50-95: {test_metrics.box.map:.4f}")
print(f"Precision: {test_metrics.box.mp:.4f} | Recall: {test_metrics.box.mr:.4f}")
# Out:
# Ultralytics 8.4.120 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLO12m summary (fused): 169 layers, 20,107,996 parameters, 0 gradients, 70.4 GFLOPs
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 9.4±1.6 MB/s, size: 42.8 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /kaggle/working/yolo_data/test/labels... 1000 images, 31 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1000/1000 266.6it/s 3.8s
# val: New cache created: /kaggle/working/yolo_data/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 1.5s/it 49.2s
#                    all       1000       2456      0.521       0.55      0.515      0.224
#               Cavities        315        662      0.464      0.497      0.435      0.163
#                 Damage        354       1060      0.442      0.397      0.388      0.139
#              Infection        252        376      0.429      0.343       0.31     0.0977
#                 Wisdom        238        358      0.751      0.961      0.929      0.495
# Speed: 1.3ms preprocess, 44.3ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to /kaggle/working/runs/bonus_dinov3_rho50_test_eval
#
# === DINOV3 @ rho=0.5 — TEST SET ===
# mAP50: 0.5153 | mAP50-95: 0.2238
# Precision: 0.5214 | Recall: 0.5496
