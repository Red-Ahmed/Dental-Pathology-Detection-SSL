# %%
RHO = 0.40                # change per notebook: 0.40 or 0.50
INIT_TYPE = 'coco'      # change per notebook: 'dinov3' or 'coco'

# %%
# !pip install ultralytics -q
from ultralytics import YOLO
import torch, pandas as pd, os

def mem():
    return f"{torch.cuda.memory_allocated()/1e9:.2f} GB"
print("Baseline:", mem())
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 21.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 5.0 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Baseline: 0.00 GB

# %%
CONFIG = {
    'architecture': 'yolo12m',
    'partition_csv': '/kaggle/input/datasets/redwanahmed2025/groupj-partb-partition/partition.csv',
    'label_fraction': RHO,
    'seed': 42, 'epochs': 50, 'img_size': 640, 'batch_size': 32, 'lr': 1e-3,
}
print(CONFIG)
# Out:
# {'architecture': 'yolo12m', 'partition_csv': '/kaggle/input/datasets/redwanahmed2025/groupj-partb-partition/partition.csv', 'label_fraction': 0.4, 'seed': 42, 'epochs': 50, 'img_size': 640, 'batch_size': 32, 'lr': 0.001}

# %%
partition = pd.read_csv(CONFIG['partition_csv'])

def build_rho_subset(rho, partition_df):
    k = int(round(rho * 10))
    return partition_df[(partition_df['role'] == 'pool') & (partition_df['pool_fold'] < k)]

d_rho_df = build_rho_subset(RHO, partition)
print(f"D_{RHO} size:", len(d_rho_df))

test_val_ids = set(partition[partition['role'].isin(['test', 'val'])]['image_id'])
overlap = test_val_ids.intersection(set(d_rho_df['image_id']))
print("Overlap (must be 0):", len(overlap))
# Out:
# D_0.4 size: 4000
# Overlap (must be 0): 0

# %%
def build_yolo_split(df, split_name, base_dir='/kaggle/working/yolo_data'):
    img_dir = f'{base_dir}/{split_name}/images'
    lbl_dir = f'{base_dir}/{split_name}/labels'
    os.makedirs(img_dir, exist_ok=True)
    os.makedirs(lbl_dir, exist_ok=True)
    for _, row in df.iterrows():
        img_src, lbl_src = row['image_path'], row['label_path']
        img_dst = f"{img_dir}/{os.path.basename(img_src)}"
        lbl_dst = f"{lbl_dir}/{os.path.basename(lbl_src)}"
        if not os.path.exists(img_dst):
            os.symlink(img_src, img_dst)
        if not os.path.exists(lbl_dst) and os.path.exists(lbl_src):
            os.symlink(lbl_src, lbl_dst)
    return img_dir, lbl_dir

val_df = partition[partition['role'] == 'val']
test_df = partition[partition['role'] == 'test']
build_yolo_split(d_rho_df, 'train')
build_yolo_split(val_df, 'val')
build_yolo_split(test_df, 'test')

print("Train:", len(os.listdir('/kaggle/working/yolo_data/train/images')))
print("Val:", len(os.listdir('/kaggle/working/yolo_data/val/images')))
print("Test:", len(os.listdir('/kaggle/working/yolo_data/test/images')))

data_yaml_content = """
path: /kaggle/working/yolo_data
train: train/images
val: val/images
test: test/images
names:
  0: Cavities
  1: Damage
  2: Infection
  3: Wisdom
"""
with open('/kaggle/working/data.yaml', 'w') as f:
    f.write(data_yaml_content)
# Out:
# Train: 4000
# Val: 1000
# Test: 1000

# %%
if INIT_TYPE == 'dinov3':
    checkpoint_dir = '/kaggle/input/datasets/kanizmithila/groupj-partb-dinov3-checkpoint'
    dinov3_state = torch.load(f'{checkpoint_dir}/dinov3_backbone.pt', map_location='cpu')

    class YOLOv12Backbone(torch.nn.Module):
        def __init__(self, full_model):
            super().__init__()
            self.layers = torch.nn.Sequential(*[full_model.model.model[i] for i in range(9)])
        def forward(self, x):
            return self.layers(x)

    fresh_model = YOLO('yolo12m.yaml')
    remapped_state = {k.replace('layers.', 'model.', 1): v for k, v in dinov3_state.items()}
    missing, unexpected = fresh_model.model.load_state_dict(remapped_state, strict=False)
    print(f"Unexpected keys (should be 0): {len(unexpected)}")
    fresh_model.save('/kaggle/working/model_initialized.pt')
    model = YOLO('/kaggle/working/model_initialized.pt')

elif INIT_TYPE == 'coco':
    model = YOLO('yolo12m.pt')

print(f"Model ready: {INIT_TYPE} @ rho={RHO}")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo12m.pt to 'yolo12m.pt': 100% ━━━━━━━━━━━━ 39.0MB 170.8MB/s 0.2s
# Model ready: coco @ rho=0.4

# %%
run_name = f'bonus_{INIT_TYPE}_rho{int(RHO*100)}'
results = model.train(
    data='/kaggle/working/data.yaml',
    epochs=CONFIG['epochs'], imgsz=CONFIG['img_size'], batch=CONFIG['batch_size'],
    lr0=CONFIG['lr'], seed=CONFIG['seed'],
    project='/kaggle/working/runs', name=run_name, exist_ok=True, patience=0,
)
# Out:
# Ultralytics 8.4.120 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/data.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo12m.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=bonus_coco_rho40, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=0, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/bonus_coco_rho40, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 16.8MB/s 0.0s
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 4]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1   1248768  ultralytics.nn.modules.block.A2C2f           [1024, 512, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1    378624  ultralytics.nn.modules.block.A2C2f           [1024, 256, 1, False, -1]
#  15                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1   1183232  ultralytics.nn.modules.block.A2C2f           [768, 512, 1, False, -1]
#  18                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  21        [14, 17, 20]  1   1414108  ultralytics.nn.modules.head.Detect           [4, 16, None, [256, 512, 512]]
# YOLOv12m summary: 292 layers, 20,140,572 parameters, 20,140,556 gradients, 71.0 GFLOPs
#
# Transferred 745/751 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 72.0MB/s 0.1s
# AMP: checks passed ✅
# WARNING ⚠️ train: Slow image access detected (ping: 0.2±0.3 ms, read: 5.6±0.6 MB/s, size: 35.9 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# train: Scanning /kaggle/working/yolo_data/train/labels... 4000 images, 81 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4000/4000 221.7it/s 18.0s
# train: New cache created: /kaggle/working/yolo_data/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 8.0±2.9 MB/s, size: 41.4 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /kaggle/working/yolo_data/val/labels... 1000 images, 6 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1000/1000 229.3it/s 4.4s
# val: New cache created: /kaggle/working/yolo_data/val/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 123 weight(decay=0.0), 130 weight(decay=0.0005), 129 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/bonus_coco_rho40/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/bonus_coco_rho40
# Starting training for 50 epochs...
# WARNING ⚠️ CUDA out of memory with batch=32. Reducing to batch=16 and retrying (1/3).
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 74.6±7.6 MB/s, size: 38.5 KB)
# train: Scanning /kaggle/working/yolo_data/train/labels.cache... 4000 images, 81 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4000/4000 1.9Git/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 63.2±9.7 MB/s, size: 35.2 KB)
# val: Scanning /kaggle/working/yolo_data/val/labels.cache... 1000 images, 6 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1000/1000 65.5Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 123 weight(decay=0.0), 130 weight(decay=0.0005), 129 bias(decay=0.0)
# : 0% ──────────── 0/125  5.2s
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING ⚠️ CUDA backend memory error with batch=16. Reducing to batch=8 and retrying (2/3).
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 58.0±26.2 MB/s, size: 34.1 KB)
# train: Scanning /kaggle/working/yolo_data/train/labels.cache... 4000 images, 81 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4000/4000 1.4Git/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 61.7±6.1 MB/s, size: 36.7 KB)
# val: Scanning /kaggle/working/yolo_data/val/labels.cache... 1000 images, 6 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1000/1000 68.8Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 123 weight(decay=0.0), 130 weight(decay=0.0005), 129 bias(decay=0.0)
# : 0% ──────────── 0/250  10.1s
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      8.06G      2.484      2.831      1.974         27        640: 100% ━━━━━━━━━━━━ 500/500 2.4it/s 3:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.6s/it 24.9s
#                    all       1000       2470      0.256      0.151      0.122     0.0482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      5.98G      2.454      2.412      1.972         30        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.7s
#                    all       1000       2470      0.303      0.382      0.309      0.134
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      5.98G      2.446      2.327      1.952         29        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.7s
#                    all       1000       2470       0.36      0.404      0.313      0.116
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      5.98G      2.365      2.214      1.893         42        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.252      0.304      0.221     0.0823
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      5.98G      2.319      2.125       1.87         27        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.5s
#                    all       1000       2470      0.351      0.388      0.357      0.149
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      5.98G      2.298      2.071      1.849         26        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.362       0.42      0.366       0.16
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      5.98G      2.285      2.061      1.831         31        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.379      0.383      0.353      0.154
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      5.98G      2.242       2.01      1.823         30        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.433      0.417      0.376      0.153
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      5.98G      2.228      1.973      1.806         30        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.473      0.437      0.395      0.173
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      5.98G      2.219      1.972      1.802         25        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.374      0.447      0.361      0.164
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      5.98G      2.196      1.929      1.786         31        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.426      0.456      0.399      0.173
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      5.98G      2.182      1.918      1.767         44        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.4s
#                    all       1000       2470      0.408      0.475      0.398       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      5.98G      2.183       1.88      1.765         22        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.4s
#                    all       1000       2470      0.412      0.446      0.376      0.154
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      5.98G      2.148      1.867       1.75         23        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.453      0.499      0.421      0.186
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      5.98G       2.15      1.852      1.737         30        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.427      0.496      0.432      0.188
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      5.98G      2.159      1.848      1.747         18        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.425      0.494      0.415      0.181
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      5.98G       2.14      1.843      1.728         44        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.5s
#                    all       1000       2470      0.427      0.489      0.432      0.191
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      5.98G      2.116       1.83      1.725         34        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.462      0.497      0.431      0.196
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      5.98G      2.102      1.803      1.715         23        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.5s
#                    all       1000       2470      0.449      0.486      0.437      0.191
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      5.98G      2.114      1.814      1.707         32        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.438      0.481      0.413      0.177
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      5.98G      2.107      1.807      1.712         35        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.5s
#                    all       1000       2470      0.466      0.513      0.444      0.195
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      5.98G       2.09      1.796      1.704         25        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.452      0.531      0.444      0.198
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      5.98G       2.08      1.761      1.703         15        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.5s
#                    all       1000       2470      0.468      0.538      0.463      0.205
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      5.98G      2.069      1.766      1.692         17        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.459      0.496      0.444      0.197
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      5.98G      2.056      1.729      1.682         15        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.454      0.527      0.457      0.204
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      5.98G      2.044      1.704      1.672         22        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.473      0.506      0.445      0.201
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      5.98G      2.046      1.708      1.674         21        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.467      0.535      0.458      0.208
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      5.98G      2.032      1.712      1.664         21        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.7s
#                    all       1000       2470      0.475       0.51      0.461       0.21
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      5.98G      2.026        1.7      1.663         26        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.5s
#                    all       1000       2470      0.469        0.5      0.447      0.198
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      5.98G      2.019      1.683      1.653         27        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.4s
#                    all       1000       2470      0.459      0.526      0.475      0.213
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      5.99G      2.013      1.673      1.646         29        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.5s
#                    all       1000       2470      0.479      0.505      0.469      0.212
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      5.98G      2.016      1.695       1.66         19        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.469       0.51      0.461      0.205
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      5.98G      1.999       1.65      1.648         29        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.5s
#                    all       1000       2470      0.476      0.542      0.478      0.217
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      5.98G      1.989      1.662      1.652         23        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.476      0.527      0.481      0.216
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      5.98G      1.979      1.646      1.626         30        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.5s
#                    all       1000       2470      0.474      0.532      0.479      0.216
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      5.98G      1.974      1.624      1.615         28        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.463      0.553      0.482      0.217
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      5.98G      1.968      1.589      1.631         35        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.479      0.544      0.479      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      5.98G       1.96      1.598      1.617         44        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.5s
#                    all       1000       2470      0.481      0.536      0.493      0.226
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      5.98G      1.944      1.582      1.612         22        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.491      0.552      0.498      0.226
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      5.98G      1.943      1.571      1.606         31        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.5s
#                    all       1000       2470      0.498       0.55      0.491      0.223
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      5.98G      1.917      1.562      1.715         12        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.5s
#                    all       1000       2470      0.522      0.536      0.494      0.226
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      5.98G      1.914      1.542      1.712         23        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.517       0.53      0.497      0.228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      5.98G      1.901      1.518      1.716         21        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.513      0.553      0.504      0.226
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      5.98G      1.897       1.49      1.692         26        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.5s
#                    all       1000       2470      0.526      0.541      0.505       0.23
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      5.98G      1.877      1.495      1.692         12        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470       0.53      0.541       0.51      0.233
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      5.99G      1.878      1.479      1.701         13        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.522      0.551      0.511      0.234
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      5.98G       1.86      1.461      1.684         18        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.5s
#                    all       1000       2470      0.513      0.558      0.513      0.233
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      5.98G      1.843      1.454      1.676         25        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.522       0.55      0.512      0.235
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      5.98G      1.837      1.436      1.674         19        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.527      0.552      0.512      0.235
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      5.98G      1.834      1.436      1.668         20        640: 100% ━━━━━━━━━━━━ 500/500 2.5it/s 3:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.3s/it 20.6s
#                    all       1000       2470      0.515       0.55      0.511      0.235
#
# 50 epochs completed in 3.110 hours.
# Optimizer stripped from /kaggle/working/runs/bonus_coco_rho40/weights/last.pt, 40.8MB
# Optimizer stripped from /kaggle/working/runs/bonus_coco_rho40/weights/best.pt, 40.8MB
#
# Validating /kaggle/working/runs/bonus_coco_rho40/weights/best.pt...
# Ultralytics 8.4.120 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLOv12m summary (fused): 169 layers, 20,107,996 parameters, 0 gradients, 70.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 1.2s/it 20.0s
#                    all       1000       2470      0.528      0.552      0.512      0.236
#               Cavities        315        657       0.45      0.467      0.416       0.16
#                 Damage        354       1094       0.44       0.48      0.391      0.142
#              Infection        252        357      0.429      0.322      0.305      0.105
#                 Wisdom        238        362      0.793      0.939      0.937      0.534
# Speed: 0.2ms preprocess, 16.0ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /kaggle/working/runs/bonus_coco_rho40

# %%
best_model = YOLO(f'/kaggle/working/runs/{run_name}/weights/best.pt')
test_metrics = best_model.val(
    data='/kaggle/working/data.yaml', split='test',
    imgsz=CONFIG['img_size'], batch=CONFIG['batch_size'],
    project='/kaggle/working/runs', name=f'{run_name}_test_eval', exist_ok=True,
)
print(f"\n=== {INIT_TYPE.upper()} @ rho={RHO} — TEST SET ===")
print(f"mAP50: {test_metrics.box.map50:.4f} | mAP50-95: {test_metrics.box.map:.4f}")
print(f"Precision: {test_metrics.box.mp:.4f} | Recall: {test_metrics.box.mr:.4f}")
# Out:
# Ultralytics 8.4.120 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLOv12m summary (fused): 169 layers, 20,107,996 parameters, 0 gradients, 70.4 GFLOPs
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 6.8±0.6 MB/s, size: 37.9 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /kaggle/working/yolo_data/test/labels... 1000 images, 31 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1000/1000 244.3it/s 4.1s
# val: New cache created: /kaggle/working/yolo_data/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 1.3s/it 43.0s
#                    all       1000       2456      0.513      0.555       0.52      0.227
#               Cavities        315        662      0.461      0.497      0.457      0.167
#                 Damage        354       1060      0.437      0.464      0.397      0.137
#              Infection        252        376      0.373       0.33      0.291     0.0983
#                 Wisdom        238        358      0.782       0.93      0.933      0.506
# Speed: 1.4ms preprocess, 38.3ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /kaggle/working/runs/bonus_coco_rho40_test_eval
#
# === COCO @ rho=0.4 — TEST SET ===
# mAP50: 0.5197 | mAP50-95: 0.2271
# Precision: 0.5132 | Recall: 0.5553
